# %% [markdown]
# # From Experiments to Data
# ## Computational Methods in Psychology (and Neuroscience)
# ### Psychology 4215/7215 --- Fall 2021
# By: Per B. Sederberg, PhD

# %% [markdown]
# # Lesson Objectives
#
# Upon completion of this lesson, students should have learned:
#
# 1. How to polish up a complete experiment
# 2. How SMILE stores data
# 3. How to read in slog files
# 4. An introduction to Pandas

# %% [markdown]
# # Review list generation solution
#
# - Let's go through the list gen code you'll use for your next assignment!

# %% [markdown]
# # Subject Info
#
# - When collecting data from a lot of participants in a lab setting, you need an easy way to enter subject information once the experiment has started.

# %%
from smile.common import *
from smile.startup import InputSubject

exp = Experiment(show_splash=False, resolution=(1024,768))

InputSubject('Flanker')

Label(text='Hello!')
with UntilDone():
    KeyPress()
    
exp.run()

# %% [markdown]
# # Instructions
#
# - Participants need some guidance as to how they should perform the task
# - This can be just text via `Label` states, but even better would be a visual description, and even better would be a full tutorial.
# - ***NOTE: If you provide a tutorial, do not use items that you will use for the actual task!***

# %%
from smile.common import *

exp = Experiment(show_splash=False, resolution=(1024,768))

# Labels can be multi-line with markup!
with Parallel():
    Label(text="This is multi-line text aligned to the left", 
          font_size=50, text_size=(400, None),
          left=exp.screen.left)
    Label(text="This is multi-line text aligned to the right", 
          font_size=50, text_size=(400, None), 
          right=exp.screen.right, halign='right')
with UntilDone():
    KeyPress()
    
exp.run()

# %% [markdown]
# # Scaling to different screen sizes/densities
#
# - Screen sizes and pixel densities can vary across devices (especially on laptops, tablets, and phones)
# - But all sizes in Kivy/SMILE are defined by number of pixels
# - We provide a means to scale across devices:

# %%
# load in smile states
from smile.common import *
from smile.scale import scale as s

# create an experiment instance (pick different resolutions)
resolution = (800,600)
#resolution = (1024,768)
exp = Experiment(show_splash=False, resolution=resolution,
                 scale_up=True, scale_down=True, scale_box=(400, 300))
Wait(.5)
with Parallel():
    # add a scaled rectangle
    Rectangle(width=s(250),height=s(250))
    
    # and a fixed size rectangle
    Rectangle(width=100, height=100, color='blue')
with UntilDone():
    KeyPress()

exp.run()

# %% [markdown]
# # Logging and Slogging
#
# - SMILE states automatically log themselves, so you rarely will lose information if you forget to log it.
# - It's still much easier to analyze a well-organized log file from your experiment.
# - Make use of the `Log` state to save out data.
# - All logs are stored in `.slog` files, which is short for SMILE Log.
# - These are read in as a list of dictionaries (or a dict-list):
#
# ```python
# from smile.log import log2dl
# dl = log2dl('flanker_log.slog')
# ```

# %% [markdown]
# # Where have all the data gone?
#
# - All the data files are stored in the `data` directory
#   - NOTE: Even when you don't specify a subj, it saves to a `test000` directory, so you can delete that sometimes to save space.
# - There is a hierarchical structure to the data directory:
#   - Experiment -> SubjID -> Date/Time

# %%
# !du -sh data
# Out:
# 1.4M	data

# %%
# !ls data/SMILE/test000/
# Out:
# 20210930_121744  20210930_122106  20210930_152458  20211007_124549
# 20210930_121757  20210930_122230  20210930_152801  20211007_125947
# 20210930_121804  20210930_143329  20210930_152821  20211007_130009
# 20210930_121946  20210930_144041  20210930_153142  20211007_130034
# 20210930_121952  20210930_144537  20210930_155217  20211007_130046
# 20210930_122001  20210930_145759  20210930_155329  20211007_130056
# 20210930_122018  20210930_145925  20211007_123759  20211007_130122
# 20210930_122039  20210930_150609  20211007_124533

# %%
from smile.log import log2dl
dl = log2dl('data/SMILE/test000/20210930_121744/state_KeyPress_0.slog')
dl
# Out:
# [{'instantiation_filename': 'Turn on Debug Mode for this information',
#   'instantiation_lineno': 0,
#   'name': None,
#   'start_time': 286271.466313349,
#   'end_time': 286272.50535434205,
#   'enter_time': 286271.282900669,
#   'leave_time': 286272.506153025,
#   'finalize_time': 286272.506269767,
#   'base_time': 286271.466313349,
#   'pressed': 'SPACEBAR',
#   'press_time_time': 286272.50535434205,
#   'press_time_error': 0.00024182800552807748,
#   'correct': False,
#   'rt': 1.039040993025992,
#   'log_num': 0},
#  {'instantiation_filename': 'Turn on Debug Mode for this information',
#   'instantiation_lineno': 0,
#   'name': None,
#   'start_time': 286273.00535434205,
#   'end_time': 286273.636040512,
#   'enter_time': 286272.509124796,
#   'leave_time': 286273.637198863,
#   'finalize_time': 286273.637626568,
#   'base_time': 286273.00535434205,
#   'pressed': 'SPACEBAR',
#   'press_time_time': 286273.636040512,
#   'press_time_error': 0.00029039199580438435,
#   'correct': False,
#   'rt': 0.6306861699558794,
#   'log_num': 0},
#  {'instantiation_filename': 'Turn on Debug Mode for this information',
#   'instantiation_lineno': 0,
#   'name': None,
#   'start_time': 286274.136040512,
#   'end_time': 286274.509589701,
#   'enter_time': 286273.639109974,
#   'leave_time': 286274.510717297,
#   'finalize_time': 286274.510908093,
#   'base_time': 286274.136040512,
#   'pressed': 'SPACEBAR',
#   'press_time_time': 286274.509589701,
#   'press_time_error': 0.000684603990521282,
#   'correct': False,
#   'rt': 0.3735491890111007,
#   'log_num': 0}]

# %% [markdown]
# # Let's continue learning by building together!
#
# - Remaining features to add:
#   - Instructions
#   - Loop over blocks and then trials
#   - Verify logging

# %% [markdown]
# # List Gen Function
#
# - NOTE: New addition for multiple blocks of trials

# %%
import random 
import copy

# define the conditions
conds = [{'condition': 'congruent',
          'direction': 'left',
          'stimulus': '<<<<<<<'
         },
         {'condition': 'congruent',
          'direction': 'right',
          'stimulus': '>>>>>>>'
         },
         {'condition': 'incongruent',
          'direction': 'left',
          'stimulus': '>>><>>>'
         },
         {'condition': 'incongruent',
          'direction': 'right',
          'stimulus': '<<<><<<'
         },
         {'condition': 'neutral',
          'direction': 'left',
          'stimulus': '===<==='
         },
         {'condition': 'neutral',
          'direction': 'right',
          'stimulus': '===>==='
         },]

# specify number of reps of these conditions
num_reps = 2
num_blocks = 3

# loop and create the blocks
blocks = []
for b in range(num_blocks):
    # loop and create the list
    trials = []
    for i in range(num_reps):
        # extend the trials with copies of the conditions
        trials.extend(copy.deepcopy(conds))
        
    # shuffle the trials
    random.shuffle(trials)
    
    # append the trials to the blocks
    blocks.append(trials)

print(blocks)
# Out:
# [[{'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}], [{'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}], [{'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}]]

# %% [markdown]
# # Goal for task
#
# ## High level structure
#
# - Present instructions
# - Loop over blocks
# - Within each block, loop over trials
#
# ## Trial structure
#
# - Present the correct stimulus as text on the screen
# - Wait for a response
# - Remove the stimulus
# - Wait for an inter-stimulus interval
# - Log the result of the trial

# %%
from smile.common import *
from smile.scale import scale as s

# config section
font_size = 75
resp_keys = ['F', 'J']
resp_map = {'left': 'F', 'right': 'J'}
ISI_dur = 0.5
ISI_jitter = 0.5
LOC_X_jitter = 200
LOC_Y_jitter = 100
inst_font_size = 25
inst_text = """[u][size=40]FLANKER INSTRUCTIONS[/size][/u]

In this task, you will see stimuli one at at time on the screen. 
    
Press ENTER key to continue."""

# create the experiment
exp = Experiment(name='FLANKER', show_splash=False, 
                 fullscreen=False,
                 resolution=(1024, 768), scale_box=(1024, 768))

@Subroutine
def Instruct(self):
    # show the instructions
    Label(text=inst_text, font_size=inst_font_size,
          text_size=(exp.screen.width*0.75, None),
          markup=True)
    with UntilDone():
        KeyPress(keys=['ENTER'])

@Subroutine
def Trial(self, block_num, trial_num, cur_trial):
    # pick the new stimulus location
    self.location = (jitter(self.exp.screen.center_x-LOC_X_jitter,
                            LOC_X_jitter*2),
                     jitter(self.exp.screen.center_y-LOC_Y_jitter,
                            LOC_Y_jitter*2))
    # present the stimulus
    stim = Label(text=cur_trial['stimulus'],
                 font_size=font_size,
                 center=self.location)
    with UntilDone():
        # make sure the stimulus has appeared on the screen
        Wait(until=stim.appear_time)
        
        # collect a response (with no timeout)
        kp = KeyPress(keys=resp_keys, 
                      base_time=stim.appear_time['time'],
                      correct_resp=Ref.object(resp_map)[cur_trial['direction']])
    
    # wait the ISI with jitter
    Wait(ISI_dur, jitter=ISI_jitter)

    # log the result of the trial
    Log(name='flanker', 
        log_dict=cur_trial,
        block_num=block_num,
        trial_num=trial_num,
        stim_on=stim.appear_time,
        resp=kp.pressed,
        resp_time=kp.press_time,
        rt=kp.rt,
        correct=kp.correct,
        location=self.location
       )

# Get the subj id information


# show the instructions
Instruct()
Wait(0.5)

# loop over the blocks
with Loop(blocks) as block:
    # make sure they are ready to continue
    Label(text='Press the ENTER key to\nstart the next block.', 
          font_size=font_size, halign='center')
    with UntilDone():
        KeyPress(keys=['ENTER'])

    # add in some delay before the start of the block
    Wait(ISI_dur, jitter=ISI_jitter)
    
    # loop over the trials
    with Loop(block.current) as trial:
        Trial(block.i, trial.i, trial.current)

# make sure they are ready to continue
Label(text='You are all done!!!\nPress the ENTER key to go celebrate.', 
      font_size=font_size, halign='center')
with UntilDone():
    KeyPress(keys=['ENTER'])

# run the experiment
exp.run()

# %% [markdown]
# # Read in some data from the logs

# %%
from smile.log import log2dl
dl = log2dl('data/FLANKER/test000/20211007_130711/log_flanker_0.slog')
dl
# Out:
# [{'block_num': 0,
#   'trial_num': 0,
#   'stim_on_time': 306569.269299902,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306569.8923222975,
#   'resp_time_error': 0.00022534752497449517,
#   'rt': 0.6230223954771645,
#   'correct': True,
#   'location_0': 565.9039283500274,
#   'location_1': 336.7582154358705,
#   'log_time': 306570.79416547343,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 1,
#   'stim_on_time': 306570.799816691,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306571.3687474585,
#   'resp_time_error': 0.0003150884876959026,
#   'rt': 0.5689307674765587,
#   'correct': True,
#   'location_0': 624.8102965078526,
#   'location_1': 437.37237244048015,
#   'log_time': 306572.2829832691,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 2,
#   'stim_on_time': 306572.298992042,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306572.910504536,
#   'resp_time_error': 0.00053903300431557,
#   'rt': 0.6115124939824454,
#   'correct': True,
#   'location_0': 469.4742949607663,
#   'location_1': 410.39724364390975,
#   'log_time': 306573.7265057987,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 3,
#   'stim_on_time': 306573.734620707,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306574.2267758355,
#   'resp_time_error': 0.0002514955122023821,
#   'rt': 0.4921551285078749,
#   'correct': True,
#   'location_0': 394.0573614264463,
#   'location_1': 461.13705267302976,
#   'log_time': 306575.22202018695,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 4,
#   'stim_on_time': 306575.223115972,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306575.7777290655,
#   'resp_time_error': 0.00020685349591076374,
#   'rt': 0.5546130934963003,
#   'correct': False,
#   'location_0': 694.4165810750479,
#   'location_1': 448.9055986818382,
#   'log_time': 306576.67076098575,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 5,
#   'stim_on_time': 306576.681613453,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306577.344114148,
#   'resp_time_error': 0.00019213202176615596,
#   'rt': 0.6625006949761882,
#   'correct': True,
#   'location_0': 605.1791987243805,
#   'location_1': 366.1754120501323,
#   'log_time': 306577.86220944213,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 6,
#   'stim_on_time': 306577.873013212,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306578.6496935745,
#   'resp_time_error': 0.0007493595185223967,
#   'rt': 0.7766803625272587,
#   'correct': True,
#   'location_0': 467.676683251056,
#   'location_1': 338.8721399611333,
#   'log_time': 306579.2401427465,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 7,
#   'stim_on_time': 306579.253163841,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306579.94671083346,
#   'resp_time_error': 0.00021160449250601232,
#   'rt': 0.6935469924937934,
#   'correct': True,
#   'location_0': 561.9248071709553,
#   'location_1': 384.0611704578938,
#   'log_time': 306580.5498463832,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 8,
#   'stim_on_time': 306580.5613336,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306581.181267278,
#   'resp_time_error': 0.00023110699839890003,
#   'rt': 0.6199336779536679,
#   'correct': True,
#   'location_0': 563.7554807759017,
#   'location_1': 300.70596013012704,
#   'log_time': 306582.1146029494,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 9,
#   'stim_on_time': 306582.128961474,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306582.8880917755,
#   'resp_time_error': 0.0005075465014670044,
#   'rt': 0.7591303014778532,
#   'correct': True,
#   'location_0': 367.995461907812,
#   'location_1': 328.6815836403389,
#   'log_time': 306583.50431306456,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 10,
#   'stim_on_time': 306583.520289927,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306584.284090657,
#   'resp_time_error': 0.0007290480134543031,
#   'rt': 0.7638007299974561,
#   'correct': True,
#   'location_0': 640.5660305038582,
#   'location_1': 478.95437378776717,
#   'log_time': 306584.9417003138,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 11,
#   'stim_on_time': 306584.951791346,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306585.55868963804,
#   'resp_time_error': 0.00023885499103926122,
#   'rt': 0.6068982920260169,
#   'correct': True,
#   'location_0': 503.5466781030341,
#   'location_1': 413.02054675543405,
#   'log_time': 306586.3648576984,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 0,
#   'stim_on_time': 306589.954253638,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306590.693016014,
#   'resp_time_error': 0.00021474499953910708,
#   'rt': 0.7387623760150746,
#   'correct': True,
#   'location_0': 649.5368353106919,
#   'location_1': 358.15023999522197,
#   'log_time': 306591.3262017345,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 1,
#   'stim_on_time': 306591.326606164,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306591.994927814,
#   'resp_time_error': 0.00025892601115629077,
#   'rt': 0.6683216500096023,
#   'correct': True,
#   'location_0': 443.8045140388498,
#   'location_1': 477.470847275466,
#   'log_time': 306592.86645295756,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 2,
#   'stim_on_time': 306592.874722179,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306593.38992370653,
#   'resp_time_error': 0.00019613749464042485,
#   'rt': 0.515201527508907,
#   'correct': True,
#   'location_0': 543.1473531408996,
#   'location_1': 433.63833841533676,
#   'log_time': 306594.15198754356,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 3,
#   'stim_on_time': 306594.168843753,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306594.9076537165,
#   'resp_time_error': 0.00021049549104645848,
#   'rt': 0.7388099635136314,
#   'correct': True,
#   'location_0': 668.013966814597,
#   'location_1': 447.08993994220464,
#   'log_time': 306595.84653176705,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 4,
#   'stim_on_time': 306595.859168114,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306596.44911650347,
#   'resp_time_error': 0.0002151674998458475,
#   'rt': 0.5899483894463629,
#   'correct': True,
#   'location_0': 384.5194835216794,
#   'location_1': 449.7978086292825,
#   'log_time': 306597.0351254049,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 5,
#   'stim_on_time': 306597.047314365,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306597.56468083453,
#   'resp_time_error': 0.00023187350598163903,
#   'rt': 0.5173664695466869,
#   'correct': True,
#   'location_0': 571.2913941160282,
#   'location_1': 319.1253434126579,
#   'log_time': 306598.442760761,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 6,
#   'stim_on_time': 306598.446246578,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306598.9625798945,
#   'resp_time_error': 0.0005391224985942245,
#   'rt': 0.5163333165110089,
#   'correct': True,
#   'location_0': 649.7155174734307,
#   'location_1': 313.3746581284872,
#   'log_time': 306599.91799759783,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 7,
#   'stim_on_time': 306599.925628878,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306600.6347228465,
#   'resp_time_error': 0.00024410249898210168,
#   'rt': 0.7090939685003832,
#   'correct': True,
#   'location_0': 407.30545020602136,
#   'location_1': 473.4616055263511,
#   'log_time': 306601.5345848763,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 8,
#   'stim_on_time': 306601.551662689,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306602.05505450803,
#   'resp_time_error': 0.00026918199728243053,
#   'rt': 0.5033918190165423,
#   'correct': True,
#   'location_0': 403.1545008629253,
#   'location_1': 461.0967659938168,
#   'log_time': 306602.56358130317,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 9,
#   'stim_on_time': 306602.572849251,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306603.3440114105,
#   'resp_time_error': 0.00025264950818382204,
#   'rt': 0.7711621595080942,
#   'correct': True,
#   'location_0': 475.8649503188988,
#   'location_1': 339.0442195731065,
#   'log_time': 306604.21418780216,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 10,
#   'stim_on_time': 306604.228450886,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306604.825188168,
#   'resp_time_error': 0.00027049300842918456,
#   'rt': 0.5967372820014134,
#   'correct': False,
#   'location_0': 658.2374706197526,
#   'location_1': 300.12792268602885,
#   'log_time': 306605.46911710524,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 11,
#   'stim_on_time': 306605.477803918,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306606.0420831335,
#   'resp_time_error': 0.00021534849656745791,
#   'rt': 0.5642792154685594,
#   'correct': True,
#   'location_0': 628.7823143555054,
#   'location_1': 470.39707481266055,
#   'log_time': 306606.77323895134,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 0,
#   'stim_on_time': 306608.531383231,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306609.1312342285,
#   'resp_time_error': 0.00022252148482948542,
#   'rt': 0.5998509975033812,
#   'correct': True,
#   'location_0': 486.80515617336846,
#   'location_1': 340.13085360289796,
#   'log_time': 306609.7574588244,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 1,
#   'stim_on_time': 306609.761970262,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306610.305935947,
#   'resp_time_error': 0.0002613529795780778,
#   'rt': 0.5439656850066967,
#   'correct': True,
#   'location_0': 472.7308366037122,
#   'location_1': 424.1029411200004,
#   'log_time': 306611.217505863,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 2,
#   'stim_on_time': 306611.221025546,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306611.76058253855,
#   'resp_time_error': 0.00018006950267590582,
#   'rt': 0.5395569925312884,
#   'correct': True,
#   'location_0': 661.7080148410986,
#   'location_1': 419.13107198730563,
#   'log_time': 306612.5470421394,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 3,
#   'stim_on_time': 306612.550287967,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306613.0174009715,
#   'resp_time_error': 0.00019330851500853896,
#   'rt': 0.4671130044735037,
#   'correct': True,
#   'location_0': 484.44880389216416,
#   'location_1': 451.0384917111506,
#   'log_time': 306613.8709902375,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 4,
#   'stim_on_time': 306613.886893586,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306614.432359766,
#   'resp_time_error': 0.00023057800717651844,
#   'rt': 0.545466179959476,
#   'correct': True,
#   'location_0': 485.4777114835638,
#   'location_1': 463.097224647919,
#   'log_time': 306615.2489990932,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 5,
#   'stim_on_time': 306615.265240103,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306615.75414542854,
#   'resp_time_error': 0.00023156750830821693,
#   'rt': 0.48890532553195953,
#   'correct': True,
#   'location_0': 351.6798330254658,
#   'location_1': 425.4031812453187,
#   'log_time': 306616.6220415525,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 6,
#   'stim_on_time': 306616.629328154,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306617.1747569445,
#   'resp_time_error': 0.0001947015116456896,
#   'rt': 0.5454287905013189,
#   'correct': True,
#   'location_0': 556.4749168288736,
#   'location_1': 307.39030109900364,
#   'log_time': 306617.8841717387,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 7,
#   'stim_on_time': 306617.891642802,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306618.5885436025,
#   'resp_time_error': 0.0002633614931255579,
#   'rt': 0.6969008005107753,
#   'correct': True,
#   'location_0': 656.2604581708456,
#   'location_1': 348.1143194944989,
#   'log_time': 306619.5377057177,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 8,
#   'stim_on_time': 306619.539756311,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306620.28456560255,
#   'resp_time_error': 0.0002591045049484819,
#   'rt': 0.7448092915583402,
#   'correct': True,
#   'location_0': 660.968947064556,
#   'location_1': 425.09035520802615,
#   'log_time': 306620.9719447339,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 9,
#   'stim_on_time': 306620.987706803,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306621.7058993685,
#   'resp_time_error': 0.00020384450908750296,
#   'rt': 0.7181925654876977,
#   'correct': True,
#   'location_0': 471.57922432392377,
#   'location_1': 479.3099504279105,
#   'log_time': 306622.2579310281,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 10,
#   'stim_on_time': 306622.273031456,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 306622.93997652095,
#   'resp_time_error': 0.00029576299129985273,
#   'rt': 0.6669450649642386,
#   'correct': True,
#   'location_0': 478.2502264960025,
#   'location_1': 455.01590539819415,
#   'log_time': 306623.7173880724,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 11,
#   'stim_on_time': 306623.734351161,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 306624.3667474255,
#   'resp_time_error': 0.0012025304895360023,
#   'rt': 0.632396264525596,
#   'correct': True,
#   'location_0': 443.4325968807234,
#   'location_1': 418.3366008032596,
#   'log_time': 306625.2723427934,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0}]

# %%
import pandas as pd

df = pd.DataFrame(dl)
df.head()
# Out:
#    block_num  trial_num   stim_on_time  stim_on_error resp  resp_time_time  \
# 0          0          0  306569.269300            0.0    J   306569.892322
# 1          0          1  306570.799817            0.0    F   306571.368747
# 2          0          2  306572.298992            0.0    F   306572.910505
# 3          0          3  306573.734621            0.0    J   306574.226776
# 4          0          4  306575.223116            0.0    J   306575.777729
#
#    resp_time_error        rt  correct  location_0  location_1       log_time  \
# 0         0.000225  0.623022     True  565.903928  336.758215  306570.794165
# 1         0.000315  0.568931     True  624.810297  437.372372  306572.282983
# 2         0.000539  0.611512     True  469.474295  410.397244  306573.726506
# 3         0.000251  0.492155     True  394.057361  461.137053  306575.222020
# 4         0.000207  0.554613    False  694.416581  448.905599  306576.670761
#
#      condition direction stimulus  log_num
# 0    congruent     right  >>>>>>>        0
# 1    congruent      left  <<<<<<<        0
# 2      neutral      left  ===<===        0
# 3      neutral     right  ===>===        0
# 4  incongruent      left  >>><>>>        0

# %% [markdown]
# ## Assignment before next class
#
# - Your SMILE experiment is due next Thursday!
#
# ### See you next week!!!
