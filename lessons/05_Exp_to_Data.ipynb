# %% [markdown]
# # From Experiments to Data
# ## Computational Methods in Psychology and Neuroscience
# ### Psychology 4215/7215 --- Fall 2023
# By: Per B. Sederberg, PhD

# %% [markdown]
# # Lesson Objectives
#
# Upon completion of this lesson, students should have learned:
#
# 1. How to polish up a complete experiment
# 2. How SMILE stores data
# 3. How to read in slog files
# 4. An introduction to Pandas

# %% [markdown]
# # Review list generation solution
#
# - Let's go through the list gen code you'll use for your next assignment!

# %% [markdown]
# # Subject Info
#
# - When collecting data from a lot of participants in a lab setting, you need an easy way to enter subject information once the experiment has started.

# %%
from smile.common import *
from smile.startup import InputSubject

exp = Experiment(show_splash=False, resolution=(1024,768), 
                 scale_up=True, scale_down=True, 
                 scale_box=(1000, 750))

InputSubject('Flanker')

Label(text='Hello!')
with UntilDone():
    KeyPress()
    
exp.run()

# %% [markdown]
# # Instructions
#
# - Participants need some guidance as to how they should perform the task
# - This can be just text via `Label` states, but even better would be a visual description, and even better would be a full tutorial.
# - ***NOTE: If you provide a tutorial, do not use items that you will use for the actual task!***

# %%
from smile.common import *

exp = Experiment(show_splash=False, resolution=(1024,768))

# Labels can be multi-line with markup!
with Parallel():
    Label(text="This is multi-line text aligned to the left", 
          font_size=50, text_size=(600, None),
          left=exp.screen.left)
    Label(text="This is multi-line text aligned to the right", 
          font_size=50, text_size=(600, None), 
          right=exp.screen.right, halign='right')
with UntilDone():
    KeyPress()
    
exp.run()

# %% [markdown]
# # Scaling to different screen sizes/densities
#
# - Screen sizes and pixel densities can vary across devices (especially on laptops, tablets, and phones)
# - But all sizes in Kivy/SMILE are defined by number of pixels
# - We provide a means to scale across devices:

# %%
# load in smile states
from smile.common import *
from smile.scale import scale as s

# create an experiment instance (pick different resolutions)
resolution = (400,300)
#resolution = (800,600)
#resolution = (1024,768)
exp = Experiment(show_splash=False, resolution=resolution,
                 scale_up=True, scale_down=True, 
                 scale_box=(400, 300))
Wait(.5)
with Parallel():
    # add a scaled rectangle
    Rectangle(width=s(250),height=s(250), color='red')
    
    # and a fixed size rectangle
    rect = Rectangle(width=100, height=100, color='blue')
    
    Label(text="Blue", bottom=rect.top, fontsize=s(50))
with UntilDone():
    KeyPress()

exp.run()

# %% [markdown]
# # Logging and Slogging
#
# - SMILE states automatically log themselves, so you rarely will lose information if you forget to log it.
# - It's still much easier to analyze a well-organized log file from your experiment.
# - Make use of the `Log` state to save out data.
# - All logs are stored in `.slog` files, which is short for SMILE Log.
# - These are read in as a list of dictionaries (or a dict-list):
#
# ```python
# from smile.log import log2dl
# dl = log2dl('flanker_log.slog')
# ```

# %% [markdown]
# # Where have all the data gone?
#
# - All the data files are stored in the `data` directory
#   - NOTE: Even when you don't specify a subj, it saves to a `test000` directory, so you can delete that sometimes to save space.
# - There is a hierarchical structure to the data directory:
#   - Experiment -> SubjID -> Date/Time

# %%
# !du -sh data
# Out:
# 1.4M	data

# %%
# !ls data/SMILE/test000/
# Out:
# 20230907_002217  20230907_150037  20230914_104602  20230914_145307
# 20230907_002319  20230907_160531  20230914_104621  20230914_145716
# 20230907_004819  20230907_160546  20230914_111058  20230914_150053
# 20230907_004823  20230907_160610  20230914_111249  20230914_151750
# 20230907_004836  20230907_161810  20230914_112306  20230914_152130
# 20230907_004858  20230907_162329  20230914_112316  20230914_152644
# 20230907_103848  20230907_162413  20230914_112524  20230914_153137
# 20230907_103925  20230907_162421  20230914_113326  20230914_153155
# 20230907_104009  20230907_162436  20230914_114139  20230914_153241
# 20230907_113136  20230907_162448  20230914_114452  20230914_153354
# 20230907_113245  20230914_092020  20230914_114640  20230914_160001
# 20230907_113319  20230914_092225  20230914_114906  20230917_131051
# 20230907_113329  20230914_092251  20230914_114916  20230917_131127
# 20230907_113420  20230914_092304  20230914_134250  20230917_131139
# 20230907_113705  20230914_092353  20230914_134422  20230920_234739
# 20230907_114043  20230914_092423  20230914_143044  20230920_234838
# 20230907_145141  20230914_095148  20230914_143648
# 20230907_145309  20230914_104510  20230914_145109

# %%
from smile.log import log2dl
dl = log2dl('data/SMILE/test000/20230920_234838/state_KeyPress_0.slog')
dl
# Out:
# [{'instantiation_filename': 'Turn on Debug Mode for this information',
#   'instantiation_lineno': 0,
#   'name': None,
#   'start_time': 1411736.494129947,
#   'end_time': 1411738.4637933115,
#   'enter_time': 1411736.249198686,
#   'leave_time': 1411738.464830402,
#   'finalize_time': 1411738.464898925,
#   'base_time': 1411736.494129947,
#   'pressed': 'F',
#   'press_time_time': 1411738.4637933115,
#   'press_time_error': 0.0006595384329557419,
#   'correct': False,
#   'rt': 1.969663364579901,
#   'log_num': 0}]

# %% [markdown]
# # Let's continue learning by building together!
#
# - Remaining features to add:
#   - Instructions
#   - Loop over blocks and then trials
#   - Verify logging

# %% [markdown]
# # List Gen Function
#
# - NOTE: New addition for multiple blocks of trials

# %%
import random 
import copy

# define the conditions
conds = [{'condition': 'congruent',
          'direction': 'left',
          'stimulus': '<<<<<<<'
         },
         {'condition': 'congruent',
          'direction': 'right',
          'stimulus': '>>>>>>>'
         },
         {'condition': 'incongruent',
          'direction': 'left',
          'stimulus': '>>><>>>'
         },
         {'condition': 'incongruent',
          'direction': 'right',
          'stimulus': '<<<><<<'
         },
         {'condition': 'neutral',
          'direction': 'left',
          'stimulus': '===<==='
         },
         {'condition': 'neutral',
          'direction': 'right',
          'stimulus': '===>==='
         },]

# specify number of reps of these conditions
num_reps = 2
num_blocks = 3

# loop and create the blocks
blocks = []
for b in range(num_blocks):
    # loop and create the list
    trials = []
    for i in range(num_reps):
        # extend the trials with copies of the conditions
        trials.extend(copy.deepcopy(conds))
        
    # shuffle the trials
    random.shuffle(trials)
    
    # append the trials to the blocks
    blocks.append(trials)

print(blocks)
# Out:
# [[{'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}], [{'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}], [{'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'incongruent', 'direction': 'left', 'stimulus': '>>><>>>'}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'left', 'stimulus': '===<==='}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}, {'condition': 'congruent', 'direction': 'right', 'stimulus': '>>>>>>>'}, {'condition': 'neutral', 'direction': 'right', 'stimulus': '===>==='}, {'condition': 'congruent', 'direction': 'left', 'stimulus': '<<<<<<<'}, {'condition': 'incongruent', 'direction': 'right', 'stimulus': '<<<><<<'}]]

# %% [markdown]
# # Goal for task
#
# ## High level structure
#
# - Present instructions
# - Loop over blocks
# - Within each block, loop over trials
#
# ## Trial structure
#
# - Present the correct stimulus as text on the screen
# - Wait for a response
# - Remove the stimulus
# - Wait for an inter-stimulus interval
# - Log the result of the trial

# %%
from smile.common import *
from smile.scale import scale as s

# config section
font_size = 75
resp_keys = ['F', 'J']
resp_map = {'left': 'F', 'right': 'J'}
ISI_dur = 0.5
ISI_jitter = 0.5
LOC_X_jitter = 200
LOC_Y_jitter = 100
inst_font_size = 25
inst_text = """[u][size=40]FLANKER INSTRUCTIONS[/size][/u]

In this task, you will see stimuli one at at time on the screen. 
    
Press ENTER key to continue."""

# create the experiment
exp = Experiment(name='FLANKER', show_splash=False, 
                 fullscreen=False,
                 resolution=(1024, 768), scale_box=(1024, 768))

@Subroutine
def Instruct(self):
    # show the instructions
    Label(text=inst_text, font_size=inst_font_size,
          text_size=(exp.screen.width*0.75, None),
          markup=True)
    with UntilDone():
        KeyPress(keys=['ENTER'])

@Subroutine
def Trial(self, block_num, trial_num, cur_trial):
    # pick the new stimulus location
    self.location = (jitter(self.exp.screen.center_x-LOC_X_jitter,
                            LOC_X_jitter*2),
                     jitter(self.exp.screen.center_y-LOC_Y_jitter,
                            LOC_Y_jitter*2))
    # present the stimulus
    stim = Label(text=cur_trial['stimulus'],
                 font_size=font_size,
                 center=self.location)
    with UntilDone():
        # make sure the stimulus has appeared on the screen
        Wait(until=stim.appear_time)
        
        # collect a response (with no timeout)
        kp = KeyPress(keys=resp_keys, 
                      base_time=stim.appear_time['time'],
                      correct_resp=Ref.object(resp_map)[cur_trial['direction']])
    
    # wait the ISI with jitter
    Wait(ISI_dur, jitter=ISI_jitter)

    # log the result of the trial
    Log(name='flanker', 
        log_dict=cur_trial,
        block_num=block_num,
        trial_num=trial_num,
        stim_on=stim.appear_time,
        resp=kp.pressed,
        resp_time=kp.press_time,
        rt=kp.rt,
        correct=kp.correct,
        location=self.location
       )

# Get the subj id information


# show the instructions
Instruct()
Wait(0.5)

# loop over the blocks
with Loop(blocks) as block:
    # make sure they are ready to continue
    Label(text='Press the ENTER key to\nstart the next block.', 
          font_size=font_size, halign='center')
    with UntilDone():
        KeyPress(keys=['ENTER'])

    # add in some delay before the start of the block
    Wait(ISI_dur, jitter=ISI_jitter)
    
    # loop over the trials
    with Loop(block.current) as trial:
        Trial(block.i, trial.i, trial.current)

# make sure they are ready to continue
Label(text='You are all done!!!\nPress the ENTER key to go celebrate.', 
      font_size=font_size, halign='center')
with UntilDone():
    KeyPress(keys=['ENTER'])

# run the experiment
exp.run()

# %% [markdown]
# # Read in some data from the logs

# %%
from smile.log import log2dl
dl = log2dl('data/FLANKER/test000/20230921_120950/log_flanker_0.slog')
dl
# Out:
# [{'block_num': 0,
#   'trial_num': 0,
#   'stim_on_time': 1427074.569719217,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427075.304962115,
#   'resp_time_error': 0.00022440101020038128,
#   'rt': 0.7352428978774697,
#   'correct': True,
#   'location_0': 377.527008863294,
#   'location_1': 377.9792209665405,
#   'log_time': 1427076.2610206704,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 1,
#   'stim_on_time': 1427076.275113663,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427077.013456764,
#   'resp_time_error': 0.00022043799981474876,
#   'rt': 0.7383431009948254,
#   'correct': True,
#   'location_0': 710.0734405646895,
#   'location_1': 480.5401723545676,
#   'log_time': 1427078.0035128118,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 2,
#   'stim_on_time': 1427078.011423538,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427078.6204291745,
#   'resp_time_error': 0.00047257449477910995,
#   'rt': 0.6090056365355849,
#   'correct': True,
#   'location_0': 367.07941679093386,
#   'location_1': 410.74572947443033,
#   'log_time': 1427079.3036215191,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 3,
#   'stim_on_time': 1427079.316162465,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427080.1332012974,
#   'resp_time_error': 0.00021713844034820795,
#   'rt': 0.8170388324651867,
#   'correct': True,
#   'location_0': 590.8534889532739,
#   'location_1': 425.8569778037995,
#   'log_time': 1427080.6347842673,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 4,
#   'stim_on_time': 1427080.641496672,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427081.508416173,
#   'resp_time_error': 0.0002431049942970276,
#   'rt': 0.8669195009861141,
#   'correct': True,
#   'location_0': 318.4165812500248,
#   'location_1': 475.6754535014363,
#   'log_time': 1427082.472096544,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 5,
#   'stim_on_time': 1427082.488652513,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427083.149049892,
#   'resp_time_error': 0.0002166170161217451,
#   'rt': 0.660397379193455,
#   'correct': True,
#   'location_0': 562.8541766056081,
#   'location_1': 480.4099209789771,
#   'log_time': 1427084.0949442922,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 6,
#   'stim_on_time': 1427084.110914024,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427084.878329337,
#   'resp_time_error': 0.00043840298894792795,
#   'rt': 0.7674153130501509,
#   'correct': True,
#   'location_0': 609.5512980452987,
#   'location_1': 482.4728032190235,
#   'log_time': 1427085.5499868405,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 7,
#   'stim_on_time': 1427085.556234845,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427086.2187375487,
#   'resp_time_error': 0.0002433535410091281,
#   'rt': 0.6625027037225664,
#   'correct': True,
#   'location_0': 550.4784657210905,
#   'location_1': 458.9794367640535,
#   'log_time': 1427086.8271181518,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 8,
#   'stim_on_time': 1427086.835645022,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427087.4749884745,
#   'resp_time_error': 0.00020948052406311035,
#   'rt': 0.6393434524070472,
#   'correct': True,
#   'location_0': 429.90807348508133,
#   'location_1': 476.0103697509876,
#   'log_time': 1427088.4314249053,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 9,
#   'stim_on_time': 1427088.434714147,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427089.1197713595,
#   'resp_time_error': 0.0002658315934240818,
#   'rt': 0.6850572125986218,
#   'correct': True,
#   'location_0': 367.61171433547895,
#   'location_1': 394.60714005400104,
#   'log_time': 1427090.033898015,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 10,
#   'stim_on_time': 1427090.037587282,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427090.6561820456,
#   'resp_time_error': 0.00024357647635042667,
#   'rt': 0.6185947635676712,
#   'correct': True,
#   'location_0': 635.0291824820047,
#   'location_1': 306.97614155774767,
#   'log_time': 1427091.3827910228,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 0,
#   'trial_num': 11,
#   'stim_on_time': 1427091.385397557,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427092.0117350342,
#   'resp_time_error': 0.0002170059597119689,
#   'rt': 0.6263374772388488,
#   'correct': True,
#   'location_0': 653.5290245127244,
#   'location_1': 438.3504641470231,
#   'log_time': 1427092.7150991925,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 0,
#   'stim_on_time': 1427096.47430709,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427097.1442711656,
#   'resp_time_error': 0.00019102951046079397,
#   'rt': 0.6699640755541623,
#   'correct': True,
#   'location_0': 681.7104909999331,
#   'location_1': 303.9234972829457,
#   'log_time': 1427097.8570606846,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 1,
#   'stim_on_time': 1427097.857780558,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427098.4760222365,
#   'resp_time_error': 0.0002291104756295681,
#   'rt': 0.6182416784577072,
#   'correct': True,
#   'location_0': 657.8710364051844,
#   'location_1': 434.0929256577476,
#   'log_time': 1427099.1431610263,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 2,
#   'stim_on_time': 1427099.15468268,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427099.8513451586,
#   'resp_time_error': 0.0002177584683522582,
#   'rt': 0.6966624786145985,
#   'correct': True,
#   'location_0': 625.2487092776689,
#   'location_1': 325.4201942722033,
#   'log_time': 1427100.6134920702,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 3,
#   'stim_on_time': 1427100.628620425,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427101.2456373558,
#   'resp_time_error': 0.00029077695216983557,
#   'rt': 0.6170169308315963,
#   'correct': True,
#   'location_0': 372.4193880504605,
#   'location_1': 334.33219149323304,
#   'log_time': 1427101.7753294206,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 4,
#   'stim_on_time': 1427101.791822417,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427102.5026871911,
#   'resp_time_error': 0.00023788202088326216,
#   'rt': 0.7108647741843015,
#   'correct': True,
#   'location_0': 578.5378194938955,
#   'location_1': 434.33636298335415,
#   'log_time': 1427103.3461159305,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 5,
#   'stim_on_time': 1427103.351242462,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427103.9863156816,
#   'resp_time_error': 0.0002289885887876153,
#   'rt': 0.6350732196588069,
#   'correct': True,
#   'location_0': 703.9363311559481,
#   'location_1': 298.40074478107744,
#   'log_time': 1427104.7806703292,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 6,
#   'stim_on_time': 1427104.787212324,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427105.4916714656,
#   'resp_time_error': 0.0002021754626184702,
#   'rt': 0.7044591414742172,
#   'correct': True,
#   'location_0': 327.02688057889713,
#   'location_1': 447.83010847559876,
#   'log_time': 1427106.1426323773,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 7,
#   'stim_on_time': 1427106.154953016,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427106.7937452705,
#   'resp_time_error': 0.0001780114835128188,
#   'rt': 0.6387922544963658,
#   'correct': True,
#   'location_0': 320.0235131437848,
#   'location_1': 359.50067647290996,
#   'log_time': 1427107.30785797,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 8,
#   'stim_on_time': 1427107.318771016,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427108.0061511644,
#   'resp_time_error': 0.00023626151960343122,
#   'rt': 0.6873801483307034,
#   'correct': True,
#   'location_0': 536.4220390346686,
#   'location_1': 483.6179518793524,
#   'log_time': 1427108.6812402704,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 9,
#   'stim_on_time': 1427108.684270383,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427109.3550757745,
#   'resp_time_error': 0.00019063358195126057,
#   'rt': 0.6708053913898766,
#   'correct': True,
#   'location_0': 374.27743157177036,
#   'location_1': 475.88351474122817,
#   'log_time': 1427110.085439183,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 10,
#   'stim_on_time': 1427110.088216588,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427110.7068873951,
#   'resp_time_error': 0.0001767351059243083,
#   'rt': 0.6186708072200418,
#   'correct': True,
#   'location_0': 394.65968488941286,
#   'location_1': 451.9638610905758,
#   'log_time': 1427111.4222628006,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 1,
#   'trial_num': 11,
#   'stim_on_time': 1427111.433587384,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427112.0239483407,
#   'resp_time_error': 0.00023417046759277582,
#   'rt': 0.5903609567321837,
#   'correct': True,
#   'location_0': 434.40649183898006,
#   'location_1': 286.19561872492426,
#   'log_time': 1427112.576638439,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 0,
#   'stim_on_time': 1427114.658454237,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427115.3234269498,
#   'resp_time_error': 0.0001864020014181733,
#   'rt': 0.664972712751478,
#   'correct': True,
#   'location_0': 637.2209139359022,
#   'location_1': 371.9691237375826,
#   'log_time': 1427115.8550723018,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 1,
#   'stim_on_time': 1427115.858952522,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427116.443351422,
#   'resp_time_error': 0.00019211298786103725,
#   'rt': 0.5843988999258727,
#   'correct': True,
#   'location_0': 628.1125072713905,
#   'location_1': 388.1837018790534,
#   'log_time': 1427117.3919226667,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 2,
#   'stim_on_time': 1427117.407058197,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427118.0441023305,
#   'resp_time_error': 0.00020417943596839905,
#   'rt': 0.6370441333856434,
#   'correct': True,
#   'location_0': 665.3864307610883,
#   'location_1': 393.84308307938636,
#   'log_time': 1427118.642153896,
#   'condition': 'incongruent',
#   'direction': 'left',
#   'stimulus': '>>><>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 3,
#   'stim_on_time': 1427118.64282204,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427119.2720338595,
#   'resp_time_error': 0.0001878624316304922,
#   'rt': 0.6292118194978684,
#   'correct': True,
#   'location_0': 655.7647248826996,
#   'location_1': 323.2511828337273,
#   'log_time': 1427120.0358310696,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 4,
#   'stim_on_time': 1427120.03865532,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427120.714228621,
#   'resp_time_error': 0.0005483210552483797,
#   'rt': 0.6755733010359108,
#   'correct': True,
#   'location_0': 462.42716868183265,
#   'location_1': 336.9679769089817,
#   'log_time': 1427121.6159452908,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 5,
#   'stim_on_time': 1427121.626243061,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427122.22051367,
#   'resp_time_error': 0.0002348900306969881,
#   'rt': 0.5942706090863794,
#   'correct': True,
#   'location_0': 428.2238423449852,
#   'location_1': 452.8089481586306,
#   'log_time': 1427122.8714300005,
#   'condition': 'neutral',
#   'direction': 'left',
#   'stimulus': '===<===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 6,
#   'stim_on_time': 1427122.87885322,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427123.5022935565,
#   'resp_time_error': 0.00022422242909669876,
#   'rt': 0.6234403364360332,
#   'correct': True,
#   'location_0': 497.3838371851128,
#   'location_1': 317.9610165965871,
#   'log_time': 1427124.2111613099,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 7,
#   'stim_on_time': 1427124.213746069,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427124.982441469,
#   'resp_time_error': 0.00022515805903822184,
#   'rt': 0.7686954000964761,
#   'correct': True,
#   'location_0': 340.5065398513208,
#   'location_1': 330.500405254561,
#   'log_time': 1427125.4971223313,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 8,
#   'stim_on_time': 1427125.512514447,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427126.0978832403,
#   'resp_time_error': 0.00023572554346174002,
#   'rt': 0.5853687932249159,
#   'correct': True,
#   'location_0': 464.15734863157866,
#   'location_1': 341.2665148197247,
#   'log_time': 1427126.678927638,
#   'condition': 'congruent',
#   'direction': 'right',
#   'stimulus': '>>>>>>>',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 9,
#   'stim_on_time': 1427126.685152088,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427127.2605537735,
#   'resp_time_error': 0.0004235164960846305,
#   'rt': 0.5754016854334623,
#   'correct': True,
#   'location_0': 661.2330663495309,
#   'location_1': 297.13729913920326,
#   'log_time': 1427128.0451888482,
#   'condition': 'neutral',
#   'direction': 'right',
#   'stimulus': '===>===',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 10,
#   'stim_on_time': 1427128.054879549,
#   'stim_on_error': 0.0,
#   'resp': 'F',
#   'resp_time_time': 1427128.7128420845,
#   'resp_time_error': 0.00020414358004927635,
#   'rt': 0.657962535507977,
#   'correct': True,
#   'location_0': 441.50027344837963,
#   'location_1': 378.5225727769423,
#   'log_time': 1427129.4000369015,
#   'condition': 'congruent',
#   'direction': 'left',
#   'stimulus': '<<<<<<<',
#   'log_num': 0},
#  {'block_num': 2,
#   'trial_num': 11,
#   'stim_on_time': 1427129.407229836,
#   'stim_on_error': 0.0,
#   'resp': 'J',
#   'resp_time_time': 1427130.1706979764,
#   'resp_time_error': 0.00023829948622733355,
#   'rt': 0.763468140270561,
#   'correct': True,
#   'location_0': 688.5857389455418,
#   'location_1': 378.6792119934858,
#   'log_time': 1427130.9113194097,
#   'condition': 'incongruent',
#   'direction': 'right',
#   'stimulus': '<<<><<<',
#   'log_num': 0}]

# %%
import pandas as pd

df = pd.DataFrame(dl)
df.head()
# Out:
#    block_num  trial_num  stim_on_time  stim_on_error resp  resp_time_time  \
# 0          0          0  1.427075e+06            0.0    F    1.427075e+06
# 1          0          1  1.427076e+06            0.0    F    1.427077e+06
# 2          0          2  1.427078e+06            0.0    J    1.427079e+06
# 3          0          3  1.427079e+06            0.0    F    1.427080e+06
# 4          0          4  1.427081e+06            0.0    F    1.427082e+06
#
#    resp_time_error        rt  correct  location_0  location_1      log_time  \
# 0         0.000224  0.735243     True  377.527009  377.979221  1.427076e+06
# 1         0.000220  0.738343     True  710.073441  480.540172  1.427078e+06
# 2         0.000473  0.609006     True  367.079417  410.745729  1.427079e+06
# 3         0.000217  0.817039     True  590.853489  425.856978  1.427081e+06
# 4         0.000243  0.866920     True  318.416581  475.675454  1.427082e+06
#
#      condition direction stimulus  log_num
# 0      neutral      left  ===<===        0
# 1    congruent      left  <<<<<<<        0
# 2    congruent     right  >>>>>>>        0
# 3  incongruent      left  >>><>>>        0
# 4  incongruent      left  >>><>>>        0

# %% [markdown]
# ## Assignment before and after next class
#
# - Your memory list generation is due Sunday by midnight!
# - Start thinking about the SMILE experiment code. I will release the list generation solution on Monday. The SMILE experiment will be due two weeks from today (Thursday).
# - Run in the Flanker experiment we will make available and upload your data by Tuesday night at midnight.
#
# ### See you next week!!!
